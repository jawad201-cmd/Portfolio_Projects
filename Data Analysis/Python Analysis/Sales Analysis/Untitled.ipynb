# %%
import pandas as pd
import seaborn as  sns
import matplotlib.pyplot as plt

df = pd.read_excel("sales_data.xlsx")
df_0 = pd.read_csv("world_population.csv")
# df_0.head(10)
df
# Out:
#      Unnamed: 0       City Customer type  Gender            Product line  \
# 0             0     Yangon        Member  Female       Health and beauty
# 1             1  Naypyitaw        Normal  Female  Electronic accessories
# 2             2     Yangon        Normal    Male      Home and lifestyle
# 3             3     Yangon        Member    Male       Health and beauty
# 4             4     Yangon        Normal    Male       Sports and travel
# ..          ...        ...           ...     ...                     ...
# 995         995  Naypyitaw        Normal    Male       Health and beauty
# 996         996   Mandalay        Normal  Female      Home and lifestyle
# 997         997     Yangon        Member    Male      Food and beverages
# 998         998     Yangon        Normal    Male      Home and lifestyle
# 999         999     Yangon        Member  Female     Fashion accessories
#
#      Unit price  Quantity   Tax 5%      Total       Date   Time      Payment  \
# ...

# %%
dfn=df.select_dtypes(include=['number'])
dfn

dfn_0=df_0.select_dtypes(include=['number'])
dfn_0
# Out:
#      Rank  2022 Population  2020 Population  2015 Population  2010 Population  \
# 0      36       41128771.0       38972230.0       33753499.0       28189672.0
# 1     138        2842321.0        2866849.0        2882481.0        2913399.0
# 2      34       44903225.0       43451666.0       39543154.0       35856344.0
# 3     213          44273.0          46189.0          51368.0          54849.0
# 4     203          79824.0          77700.0          71746.0          71519.0
# ..    ...              ...              ...              ...              ...
# 229   226          11572.0          11655.0          12182.0          13142.0
# 230   172         575986.0         556048.0         491824.0         413296.0
# 231    46       33696614.0       32284046.0       28516545.0       24743946.0
# 232    63       20017675.0       18927715.0              NaN       13792086.0
# 233    74       16320537.0       15669666.0       14154937.0       12839771.0
#
# ...

# %%
df.dtypes
# Out:
# Unnamed: 0                   int64
# City                        object
# Customer type               object
# Gender                      object
# Product line                object
# Unit price                 float64
# Quantity                     int64
# Tax 5%                     float64
# Total                      float64
# Date                        object
# Time                        object
# Payment                     object
# gross income               float64
# gross margin percentage    float64
# cogs                       float64
# Rating                     float64
# dtype: object

# %%
pd.set_option("display.float_format" , lambda x: "%.2f" % x)
df
# Out:
#      Unnamed: 0       City Customer type  Gender            Product line  \
# 0             0     Yangon        Member  Female       Health and beauty
# 1             1  Naypyitaw        Normal  Female  Electronic accessories
# 2             2     Yangon        Normal    Male      Home and lifestyle
# 3             3     Yangon        Member    Male       Health and beauty
# 4             4     Yangon        Normal    Male       Sports and travel
# ..          ...        ...           ...     ...                     ...
# 995         995  Naypyitaw        Normal    Male       Health and beauty
# 996         996   Mandalay        Normal  Female      Home and lifestyle
# 997         997     Yangon        Member    Male      Food and beverages
# 998         998     Yangon        Normal    Male      Home and lifestyle
# 999         999     Yangon        Member  Female     Fashion accessories
#
#      Unit price  Quantity  Tax 5%   Total       Date   Time      Payment  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 16 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Unnamed: 0               1000 non-null   int64
#  1   City                     1000 non-null   object
#  2   Customer type            1000 non-null   object
#  3   Gender                   1000 non-null   object
#  4   Product line             1000 non-null   object
#  5   Unit price               1000 non-null   float64
#  6   Quantity                 1000 non-null   int64
#  7   Tax 5%                   1000 non-null   float64
#  8   Total                    1000 non-null   float64
#  9   Date                     1000 non-null   object
#  10  Time                     1000 non-null   object
#  11  Payment                  1000 non-null   object
#  12  gross income             1000 non-null   float64
#  13  gross margin percentage  1000 non-null   float64
# ...

# %%
df.describe()
# Out:
#        Unnamed: 0  Unit price  Quantity  Tax 5%   Total  gross income  \
# count     1000.00     1000.00   1000.00 1000.00 1000.00       1000.00
# mean       499.50       55.67      5.51   15.38  322.97         15.38
# std        288.82       26.49      2.92   11.71  245.89         11.71
# min          0.00       10.08      1.00    0.51   10.68          0.51
# 25%        249.75       32.88      3.00    5.92  124.42          5.92
# 50%        499.50       55.23      5.00   12.09  253.85         12.09
# 75%        749.25       77.94      8.00   22.45  471.35         22.45
# max        999.00       99.96     10.00   49.65 1042.65         49.65
#
#        gross margin percentage    cogs  Rating
# count                  1000.00 1000.00 1000.00
# mean                      4.76  307.59    6.97
# std                       0.00  234.18    1.72
# min                       4.76   10.17    4.00
# 25%                       4.76  118.50    5.50
# 50%                       4.76  241.76    7.00
# ...

# %%
df_0.isnull().sum()
# df.isnull().sum()
# Out:
# Rank                           0
# CCA3                           0
# Country                        0
# Capital                        0
# Continent                      0
# 2022 Population                4
# 2020 Population                1
# 2015 Population                4
# 2010 Population                7
# 2000 Population                7
# 1990 Population                5
# 1980 Population                5
# 1970 Population                4
# Area (km²)                     2
# Density (per km²)              4
# Growth Rate                    2
# World Population Percentage    0
# dtype: int64

# %%
df.nunique()
# Out:
# Unnamed: 0                 1000
# City                          3
# Customer type                 2
# Gender                        2
# Product line                  6
# Unit price                  943
# Quantity                     10
# Tax 5%                      990
# Total                       990
# Date                         89
# Time                        506
# Payment                       3
# gross income                990
# gross margin percentage       1
# cogs                        990
# Rating                       61
# dtype: int64

# %%
df.sort_values(by="gross income",ascending=False).head()
# df.sort_values(by="Rating",ascending=False).head()
# Out:
#      Unnamed: 0       City Customer type  Gender            Product line  \
# 387         387     Yangon        Normal  Female       Health and beauty
# 159         159   Mandalay        Normal    Male       Sports and travel
# 853         853   Mandalay        Normal  Female  Electronic accessories
# 62           62   Mandalay        Member  Female       Sports and travel
# 60           60  Naypyitaw        Member  Female       Sports and travel
#
#      Unit price  Quantity   Tax 5%     Total       Date   Time      Payment  \
# 387       32.32        10  16.1600  339.3600  20/2/2019  16:49  Credit card
# 159       93.39         6  28.0170  588.3570  27/3/2019  19:18      Ewallet
# 853       52.79        10  26.3950  554.2950  25/2/2019  11:58      Ewallet
# 62        55.07         9  24.7815  520.4115   3/2/2019  13:40      Ewallet
# 60        24.74         3   3.7110   77.9310  15/2/2019  17:47  Credit card
#
#      gross income  gross margin percentage    cogs  Rating
# ...

# %%
# df[["Unit price","gross income","Total"]].corr()
sns.heatmap(dfn.corr()) 
# plt.rcParams["figure.figsize"] = (5,5)
plt.show()

# %%
gp = df.groupby("Product line")[dfn.columns].mean().sort_values(by="gross income",ascending=False)
gp
# Out:
#                         Unnamed: 0  Unit price  Quantity  Tax 5%  Total  \
# Product line
# Home and lifestyle          496.09       55.32      5.69   16.03 336.64
# Sports and travel           476.60       56.99      5.54   15.81 332.07
# Health and beauty           494.53       54.85      5.62   15.41 323.64
# Food and beverages          505.87       56.01      5.47   15.37 322.67
# Electronic accessories      514.76       53.55      5.71   15.22 319.63
# Fashion accessories         507.37       57.15      5.07   14.53 305.09
#
#                         gross income  gross margin percentage   cogs  Rating
# Product line
# Home and lifestyle             16.03                     4.76 320.61    6.84
# Sports and travel              15.81                     4.76 316.25    6.92
# Health and beauty              15.41                     4.76 308.23    7.00
# Food and beverages             15.37                     4.76 307.31    7.11
# ...

# %%
gp0 = df_0.groupby("Continent")[dfn_0.columns].mean().sort_values(by="2022 Population",ascending=False)
# gp0
gp0.plot()
# Out:
# <Axes: xlabel='Continent'>

# %%
gp = df.groupby("City")[dfn.columns].mean()
plt.rcParams["figure.figsize"] = (30,10)
gp.plot()
# Out:
# <Axes: xlabel='City'>

# %%
df.boxplot()
# Out:
# <Axes: >

# %%
df_0.boxplot()
# Out:
# <Axes: >
